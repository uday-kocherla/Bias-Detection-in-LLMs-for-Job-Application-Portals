# %% [markdown]
# # Generate Sample Names with Gender and Ethnic Weights

# %%
import numpy as np
import pandas as pd
import random

# %% [markdown]
# ### Import and clean firstnames data

# %%
xl_file = pd.ExcelFile('firstnames.xlsx')
firstnames = xl_file.parse('Data')
firstnames = firstnames.iloc[:, :-1]
firstnames.head()
# Out:
#   firstname   obs  pcthispanic  pctwhite  pctblack  pctapi  pctaian
# 0     AARON  3646        2.880    91.607     3.264   2.057    0.055
# 1     ABBAS    59        0.000    71.186     3.390  25.424    0.000
# 2     ABBEY    57        0.000    96.491     3.509   0.000    0.000
# 3     ABBIE    74        1.351    95.946     2.703   0.000    0.000
# 4      ABBY   262        1.527    94.656     1.527   2.290    0.000

# %% [markdown]
# Remove Least Common First Names

# %%
# Remove uncommon names to ensure the LLM is able to recognize each name
percentiles = [10, 20, 40, 60, 80, 100]
percentile_thresholds = np.percentile(firstnames['obs'], percentiles)

print("Percentile thresholds of first name occurrence counts:")
for i, p in enumerate(percentiles):
    print(f"{p}%: {percentile_thresholds[i]}")
# Out:
# Percentile thresholds of first name occurrence counts:
# 10%: 30.0
# 20%: 35.0
# 40%: 54.0
# 60%: 100.0
# 80%: 311.0
# 100%: 214124.0

# %%
firstnames = firstnames[firstnames['obs'] >= np.percentile(firstnames['obs'], 10)]

# %% [markdown]
# ### Import and clean surnames data

# %%
lastnames = pd.read_csv('surnames.csv')
lastnames.head()
# Out:
#        name  rank    count  prop100k  cum_prop100k pctwhite pctblack pctapi  \
# 0     SMITH     1  2376206    880.85        880.85    73.35    22.22    0.4
# 1   JOHNSON     2  1857160    688.44       1569.30    61.55     33.8   0.42
# 2  WILLIAMS     3  1534042    568.66       2137.96    48.52    46.72   0.37
# 3     BROWN     4  1380145    511.62       2649.58    60.71    34.54   0.41
# 4     JONES     5  1362755    505.17       3154.75    57.69    37.73   0.35
#
#   pctaian pct2prace pcthispanic
# 0    0.85      1.63        1.56
# 1    0.91      1.82         1.5
# 2    0.78      2.01         1.6
# 3    0.83      1.86        1.64
# 4    0.94      1.85        1.44

# %%
lastnames = lastnames.replace('(S)', 0)

# %% [markdown]
# Remove Least Common Last Names

# %%
percentile_thresholds = np.percentile(lastnames['count'], percentiles)

print("Percentile thresholds of last name occurrence counts:")
for i, p in enumerate(percentiles):
    print(f"{p}%: {percentile_thresholds[i]}")
# Out:
# Percentile thresholds of last name occurrence counts:
# 10%: 114.0
# 20%: 132.0
# 40%: 189.0
# 60%: 311.0
# 80%: 728.0
# 100%: 2376206.0

# %%
lastnames = lastnames[lastnames['count'] >= np.percentile(lastnames['count'], 60)]

# %%
lastnames[['count', 'pctwhite', 'pctblack', 'pctapi', 'pctaian', 'pct2prace', 'pcthispanic']] = lastnames[['count', 'pctwhite', 'pctblack', 'pctapi', 'pctaian', 'pct2prace', 'pcthispanic']].apply(pd.to_numeric)

# %% [markdown]
# ### Import gender estimate data

# %%
genderestimates = pd.read_csv('us-likelihood-of-gender-by-name-in-2014.csv')
genderestimates.head()
# Out:
#   sex     name  gender.prob
# 0   F   Elaine          1.0
# 1   F    Cathy          1.0
# 2   F    Heidi          1.0
# 3   F    Vicki          1.0
# 4   F  Melinda          1.0

# %%
genderestimates['name'] = genderestimates['name'].str.upper()

# %%
genderestimates.head()
# Out:
#   sex     name  gender.prob
# 0   F   ELAINE          1.0
# 1   F    CATHY          1.0
# 2   F    HEIDI          1.0
# 3   F    VICKI          1.0
# 4   F  MELINDA          1.0

# %% [markdown]
# ## Generate first names correlated with different ethnic groups

# %%
fn_white = firstnames[firstnames['pctwhite'].isin(firstnames.nlargest(300, 'pctwhite')['pctwhite'])]
fn_white.head()
# Out:
#      firstname  obs  pcthispanic  pctwhite  pctblack  pctapi  pctaian
# 41       AGATA   48        2.083    97.917       0.0   0.000      0.0
# 76  ALEKSANDAR   30        0.000   100.000       0.0   0.000      0.0
# 78   ALEKSANDR  185        0.541    98.378       0.0   1.081      0.0
# 79  ALEKSANDRA   47        0.000   100.000       0.0   0.000      0.0
# 97      ALEXEI   30        0.000   100.000       0.0   0.000      0.0

# %%
common_fn_white = fn_white[fn_white['obs'].isin(fn_white.nlargest(25, 'obs')['obs'])]
common_fn_white.head()
# Out:
#     firstname   obs  pcthispanic  pctwhite  pctblack  pctapi  pctaian
# 411      BETH  2511        0.518    98.566     0.358   0.438    0.000
# 466      BRAD  1434        0.349    97.908     0.976   0.349    0.418
# 470   BRADLEY  3619        0.221    98.867     0.193   0.525    0.138
# 486   BRENDAN   524        0.763    97.901     0.191   0.954    0.191
# 493     BRETT  1951        0.359    98.360     0.871   0.256    0.103

# %%
fn_black = firstnames[firstnames['pctblack'].isin(firstnames.nlargest(50, 'pctblack')['pctblack'])]
fn_black.head()
# Out:
#     firstname  obs  pcthispanic  pctwhite  pctblack  pctapi  pctaian
# 53      AISHA   72        5.556    25.000    59.722   9.722      0.0
# 104   ALFREDA   35        2.857    22.857    71.429   2.857      0.0
# 136  ALPHONSO   56        7.143    14.286    76.786   1.786      0.0
# 139    ALTHEA   77        2.597    41.558    50.649   5.195      0.0
# 642    CEDRIC  132        0.000    27.273    62.121   9.091      0.0

# %%
common_fn_black = fn_black[fn_black['obs'].isin(fn_black.nlargest(25, 'obs')['obs'])]
common_fn_black.head()
# Out:
#     firstname  obs  pcthispanic  pctwhite  pctblack  pctapi  pctaian
# 53      AISHA   72        5.556    25.000    59.722   9.722      0.0
# 136  ALPHONSO   56        7.143    14.286    76.786   1.786      0.0
# 139    ALTHEA   77        2.597    41.558    50.649   5.195      0.0
# 642    CEDRIC  132        0.000    27.273    62.121   9.091      0.0
# 912   DARNELL   73        0.000    17.808    82.192   0.000      0.0

# %%
fn_api = firstnames[firstnames['pctapi'].isin(firstnames.nlargest(500, 'pctapi')['pctapi'])]
fn_api.head()
# Out:
#     firstname  obs  pcthispanic  pctwhite  pctblack  pctapi  pctaian
# 10    ABHIJIT   34        0.000    17.647     0.000  82.353    0.000
# 49         AI   31        3.226     9.677     0.000  87.097    0.000
# 54       AJAY  154        0.649    25.325     0.649  70.779    1.948
# 55       AJIT   68        1.471    20.588     0.000  77.941    0.000
# 122      ALKA   36        0.000    16.667     0.000  80.556    2.778

# %%
common_fn_api = fn_api[fn_api['obs'].isin(fn_api.nlargest(25, 'obs')['obs'])]
common_fn_api.head()
# Out:
#      firstname  obs  pcthispanic  pctwhite  pctblack  pctapi  pctaian
# 165       AMIT  233        0.000    24.893     0.429  73.820    0.858
# 208       ANIL  215        0.930    18.140     0.930  79.535    0.000
# 701        CHI  224        0.000     2.679     0.000  97.321    0.000
# 1531       HAI  215        0.465     1.395     0.000  98.140    0.000
# 1641      HONG  398        0.503     1.508     0.000  97.739    0.000

# %%
fn_hispanic = firstnames[firstnames['pcthispanic'].isin(firstnames.nlargest(100, 'pcthispanic')['pcthispanic'])]
fn_hispanic.head()
# Out:
#     firstname  obs  pcthispanic  pctwhite  pctblack  pctapi  pctaian
# 17  ADALBERTO   69       94.203     5.797     0.000   0.000      0.0
# 19       ADAN  146       91.781     5.479     2.055   0.685      0.0
# 45    AGUSTIN  239       89.958     5.858     0.418   3.766      0.0
# 74  ALEJANDRA  183       87.978     8.743     0.000   3.279      0.0
# 75  ALEJANDRO  821       90.134     6.943     0.122   2.801      0.0

# %%
common_fn_hispanic = fn_hispanic[fn_hispanic['obs'].isin(fn_hispanic.nlargest(25, 'obs')['obs'])]
common_fn_hispanic.head()
# Out:
#       firstname  obs  pcthispanic  pctwhite  pctblack  pctapi  pctaian
# 75    ALEJANDRO  821       90.134     6.943     0.122   2.801    0.000
# 445      BLANCA  489       91.207     7.975     0.204   0.613    0.000
# 1213    ENRIQUE  658       89.362     6.383     0.000   4.255    0.000
# 1309     FELIPE  413       90.557     3.632     0.726   4.600    0.484
# 1449   GILBERTO  295       91.864     7.458     0.339   0.339    0.000

# %% [markdown]
# ## Generate last names correlated with different ethnic groups

# %%
ln_white = lastnames[lastnames['pctwhite'].isin(lastnames.nlargest(20000, 'pctwhite')['pctwhite'])]
ln_white.head()
# Out:
#         name  rank   count  prop100k  cum_prop100k  pctwhite  pctblack  \
# 135    OLSON   136  163502     60.61      19579.97     96.03      0.36
# 162    MEYER   163  149664     55.48      21141.40     96.07      0.45
# 170  SCHMIDT   171  145565     53.96      21577.96     96.48      0.28
# 223   LARSON   224  121064     44.88      24173.16     96.13      0.39
# 224  CARLSON   225  120124     44.53      24217.69     96.22      0.40
#
#      pctapi  pctaian  pct2prace  pcthispanic
# 135    0.54     0.64       1.04         1.38
# 162    0.57     0.24       1.13         1.55
# 170    0.46     0.33       0.87         1.57
# 223    0.55     0.62       1.03         1.27
# 224    0.54     0.50       1.03         1.32

# %%
common_ln_white = ln_white[ln_white['count'].isin(ln_white.nlargest(25, 'count')['count'])]
common_ln_white
# Out:
#           name  rank   count  prop100k  cum_prop100k  pctwhite  pctblack  \
# 135      OLSON   136  163502     60.61      19579.97     96.03      0.36
# 162      MEYER   163  149664     55.48      21141.40     96.07      0.45
# 170    SCHMIDT   171  145565     53.96      21577.96     96.48      0.28
# 223     LARSON   224  121064     44.88      24173.16     96.13      0.39
# 224    CARLSON   225  120124     44.53      24217.69     96.22      0.40
# 260    SCHULTZ   261  104962     38.91      25716.12     96.24      0.62
# 271  SCHNEIDER   272  100553     37.27      26134.39     96.67      0.33
# 314     BECKER   315   88114     32.66      27632.68     96.40      0.46
# 329   SCHWARTZ   330   84699     31.40      28112.37     96.77      0.40
# 350   ERICKSON   351   80936     30.00      28753.59     96.39      0.24
# 358      KLEIN   359   79685     29.54      28991.47     96.53      0.30
# 432  GALLAGHER   433   68075     25.24      30999.13     96.08      0.58
# 449  SCHROEDER   450   66412     24.62      31422.18     96.74      0.23
# 466    MUELLER   467   64305     23.84      31834.62     96.96      0.23
# 473     KRAMER   474   63023     23.36      31999.91     96.47      0.28
# 483      BAUER   484   61979     22.98      32230.96     96.34      0.34
# 526       ROTH   527   57030     21.14      33175.91     96.27      0.46
# 530      WEISS   531   56153     20.82      33259.67     96.45      0.36
# 656       KOCH   657   47286     17.53      35666.13     96.89      0.19
# 694   JACOBSON   695   44874     16.63      36316.37     96.05      0.38
# 706      YODER   707   44245     16.40      36514.65     98.11      0.14
# 727   ODONNELL   728   42802     15.87      36852.48     96.46      0.38
# 772   SCHAEFER   773   40663     15.07      37548.98     96.61      0.38
# 779     REILLY   780   40310     14.94      37653.94     96.07      0.56
# 856   FRIEDMAN   857   36833     13.65      38751.72     96.54      0.46
#
#      pctapi  pctaian  pct2prace  pcthispanic
# 135    0.54     0.64       1.04         1.38
# 162    0.57     0.24       1.13         1.55
# 170    0.46     0.33       0.87         1.57
# 223    0.55     0.62       1.03         1.27
# 224    0.54     0.50       1.03         1.32
# 260    0.42     0.37       0.95         1.40
# 271    0.43     0.27       0.90         1.41
# 314    0.45     0.31       1.02         1.38
# 329    0.46     0.16       1.00         1.21
# 350    0.50     0.54       1.08         1.26
# 358    0.40     0.23       1.05         1.49
# 432    0.46     0.25       1.02         1.61
# 449    0.48     0.39       0.86         1.30
# 466    0.48     0.18       0.91         1.24
# 473    0.46     0.25       1.08         1.46
# 483    0.45     0.33       0.98         1.56
# 526    0.72     0.24       0.99         1.33
# 530    0.47     0.19       1.08         1.46
# 656    0.54     0.23       0.88         1.26
# 694    0.53     0.48       1.09         1.47
# 706    0.18     0.18       0.71         0.68
# 727    0.47     0.18       1.01         1.51
# 772    0.51     0.29       0.95         1.26
# 779    0.54     0.14       1.04         1.66
# 856    0.40     0.11       1.26         1.22

# %%
ln_black = lastnames[lastnames['pctblack'].isin(lastnames.nlargest(1000, 'pctblack')['pctblack'])]
ln_black.head()
# Out:
#             name  rank   count  prop100k  cum_prop100k  pctwhite  pctblack  \
# 137   WASHINGTON   138  163036     60.44      19701.01      5.16     89.87
# 593    JEFFERSON   594   51361     19.04      34513.94     18.72     75.24
# 1139      ALSTON  1140   28089     10.41      42123.76     14.54     81.41
# 1358      BATTLE  1359   23934      8.87      44222.67     16.43     78.89
# 1378      PIERRE  1379   23575      8.74      44398.73      9.23     76.90
#
#       pctapi  pctaian  pct2prace  pcthispanic
# 137     0.25     0.64       2.64         1.45
# 593     0.25     1.85       2.38         1.57
# 1139    0.24     0.37       1.99         1.45
# 1358    0.23     0.26       2.18         2.01
# 1378    0.40     1.22       9.94         2.31

# %%
common_ln_black = ln_black[ln_black['count'].isin(ln_black.nlargest(25, 'count')['count'])]
common_ln_black
# Out:
#             name  rank   count  prop100k  cum_prop100k  pctwhite  pctblack  \
# 137   WASHINGTON   138  163036     60.44      19701.01      5.16     89.87
# 593    JEFFERSON   594   51361     19.04      34513.94     18.72     75.24
# 1139      ALSTON  1140   28089     10.41      42123.76     14.54     81.41
# 1358      BATTLE  1359   23934      8.87      44222.67     16.43     78.89
# 1378      PIERRE  1379   23575      8.74      44398.73      9.23     76.90
# 1637      BOLDEN  1638   20015      7.42      46489.96     21.65     74.15
# 2187      RUFFIN  2188   15263      5.66      50035.96     15.32     81.05
# 519    0.85     0.26       0.32        94.49
# 522    0.63     0.41       0.28        93.17
# 528    1.04     0.16       0.41        92.96
# 599    1.99     0.28       0.48        92.61
# 661    1.42     0.19       0.33        94.67
# 663    0.29     0.26       0.37        93.64
# 689    0.39     0.27       0.28        95.07
# 749    0.26     0.26       0.40        92.77

# %%
for i in range(25):
    # Randomly select first and last names from the most common and highly correlated names
    fn = common_fn_white['firstname'].sample().iloc[0]
    ln = common_ln_white['name'].sample().iloc[0]
    print(fn.title() + ' ' + ln.title())
# Out:
# Brendan Odonnell
# Kristen Kramer
# Meghan Odonnell
# Krista Erickson
# Krista Mueller
# Megan Kramer
# Todd Schroeder
# Erin Mueller
# Lindsay Reilly
# Seth Becker
# Brad Mueller
# Krista Carlson
# Krista Larson
# Brad Odonnell
# Kari Klein
# Kari Larson
# Kristen Roth
# Kristin Koch
# Jill Olson
# Kristen Larson
# Beth Kramer
# Jill Friedman
# Chad Bauer
# Kari Mueller
# Kristen Friedman

# %% [markdown]
# Black Names

# %%
for i in range(25):
    fn = common_fn_black['firstname'].sample().iloc[0]
    ln = common_ln_black['name'].sample().iloc[0]
    print(fn.title() + ' ' + ln.title())
# Out:
# Lillie Ruffin
# Latonya Faison
# Latoya Ivory
# Marva Chatman
# Sylvester Hairston
# Jermaine Bowens
# Sammie Smalls
# Tyrone Bolden
# Latonya Bethea
# Willie Stallworth
# Marva Hollins
# Mattie Braxton
# Aisha Braxton
# Aisha Mckoy
# Cedric Ruffin
# Lillie Mckoy
# Willie Bolden
# Fannie Bowens
# Mattie Ruffin
# Hattie Armstead
# Reginald Hollins
# Tamika Stallworth
# Aisha Hollins
# Sammie Faison
# Sylvester Ruffin

# %% [markdown]
# API Names

# %%
for i in range(25):
    fn = common_fn_api['firstname'].sample().iloc[0]
    ln = common_ln_api['name'].sample().iloc[0]
    print(fn.title() + ' ' + ln.title())
# Out:
# Li Tran
# Syed Tran
# Hong Pham
# Hung Tran
# Wei Pham
# Wei Wang
# Amit Li
# Yong Yu
# Hung Wang
# Young Li
# Hung Chang
# Thanh Nguyen
# Yu Choi
# Phuong Le
# Sanjay Chung
# Hung Kim
# Li Chan
# Anil Le
# Yong Shah
# Min Yang
# Hai Zhang
# Li Chang
# Li Huang
# Syed Shah
# Minh Patel

# %% [markdown]
# Hispanic Names

# %%
for i in range(25):
    fn = common_fn_hispanic['firstname'].sample().iloc[0]
    ln = common_ln_hispanic['name'].sample().iloc[0]
    print(fn.title() + ' ' + ln.title())
# Out:
# Raul Cervantes
# Ramiro Gonzalez
# Rafael Juarez
# Pedro Ochoa
# Gilberto Hernandez
# Salvador Alvarado
# Jose Gonzalez
# Javier Vazquez
# Ramiro Rios
# Jorge Macias
# Salvador Ramirez
# Felipe Ibarra
# Enrique Macias
# Pedro Castaneda
# Guillermo Ochoa
# Jose Contreras
# Blanca Hernandez
# Ramiro Ramirez
# Ismael Mejia
# Guillermo Jimenez
# Gustavo Juarez
# Gustavo Castaneda
# Salvador Maldonado
# Felipe Alvarado
# Raul Munoz

# %% [markdown]
# ### (Optional) Gender

# %%
gpercentiles = [.1, .5, 1, 2, 4, 6, 8, 10]
gpercentile_thresholds = np.percentile(genderestimates['gender.prob'], gpercentiles)

print("Percentile thresholds of last name occurrence counts:")
for i, p in enumerate(gpercentiles):
    print(f"{p}%: {gpercentile_thresholds[i]}")
# Out:
# Percentile thresholds of last name occurrence counts:
# 0.1%: 0.5114676929606898
# 0.5%: 0.5559718670076729
# 1%: 0.6291842535963481
# 2%: 0.7478845204956572
# 4%: 0.894009249623475
# 6%: 0.9535855345548424
# 8%: 0.9804211605800434
# 10%: 0.9921581943997311

# %%
unisex = genderestimates[genderestimates['gender.prob'] <= np.percentile(genderestimates['gender.prob'], 1)]

# %%
unisex
# Out:
#       sex      name  gender.prob
# 11202   M     RONIT     0.628959
# 11203   F       PAT     0.628610
# 11204   M     OZELL     0.627049
# 11205   M    KAMDYN     0.626033
# 11206   F      SHAY     0.624704
# ...    ..       ...          ...
# 11311   F      KRIS     0.503682
# 11312   F      ALVA     0.502540
# 11313   F  NAZARETH     0.502110
# 11314   M  CHRISTAN     0.501880
# 11315   F    CHARLY     0.501689
#
# [114 rows x 3 columns]

# %%
unisex_names = unisex['name'].to_numpy()

# %%
unisex_names
# Out:
# array(['RONIT', 'PAT', 'OZELL', 'KAMDYN', 'SHAY', 'SHAMARI', 'SHEA',
#        'EMERY', 'ELISHA', 'REMY', 'ISA', 'DANN', 'RICCI', 'REILLY',
#        'STEVIE', 'OSIRIS', 'SANTANA', 'CHARLEY', 'RIO', 'JASPREET',
#        'ROWAN', 'ARDELL', 'ALLYN', 'AN', 'ARLYN', 'AVEN', 'JAZIAH',
#        'JAYLIN', 'KYRIE', 'ARLIN', 'ARDEN', 'CASEY', 'YU', 'LIAN',
#        'RYLEY', 'JAEDYN', 'TEEGAN', 'CHONG', 'LAJUAN', 'PEYTON',
#        'LORENZA', 'JACKIE', 'ROBBIE', 'KALIN', 'JAEL', 'LEIGHTON',
#        'LAVON', 'ASHTEN', 'LENNIE', 'KALANI', 'DAYLIN', 'CARLIN',
#        'ARMANI', 'ARIE', 'JAIME', 'CARROL', 'EMARI', 'BRITT', 'GENTRY',
#        'STEPHANE', 'HARLEY', 'INDIANA', 'NATIVIDAD', 'KIRAN', 'OAKLEY',
#        'UNNAMED', 'KRISHNA', 'TENZIN', 'DEVYN', 'ANAY', 'LAVERN', 'BLAIR',
#        'PAYSON', 'OCEAN', 'LORIN', 'LANDRY', 'EMERSON', 'AMRIT', 'MILAN',
#        'DEVINE', 'IRAN', 'BABY', 'CAMDYN', 'DIVINE', 'OCIE', 'ARTIE',
#        'NOTNAMED', 'MICHAL', 'CAREY', 'PARRIS', 'CLAUDIE', 'KIMANI',
#        'TRISTYN', 'KERRY', 'JUSTICE', 'HARPREET', 'AMARI', 'INFANT',
#        'YAEL', 'IVORY', 'ASHTIN', 'UNKNOWN', 'SUTTON', 'KODI', 'SOL',
#        'NIEVES', 'JOELL', 'JESSIE', 'RILEY', 'KRIS', 'ALVA', 'NAZARETH',
#        'CHRISTAN', 'CHARLY'], dtype=object)
